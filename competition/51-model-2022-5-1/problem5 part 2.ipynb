# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
import cvxpy as cp
from math import ceil

data = pd.read_excel('data.xlsx', header=None).values.flatten()

# %%
requirements = np.concatenate([data, [102., 102., 103., 103., 104., 104., 105., 105.]])
requirements
# Out:
# array([ 11.,   5.,   4.,   7.,  16.,   6.,   5.,   7.,  13.,   6.,   5.,
#          7.,  12.,   5.,   4.,   6.,   9.,   5.,   5.,  11.,  29.,  21.,
#         17.,  20.,  27.,  13.,   9.,  10.,  16.,   6.,   5.,   7.,  11.,
#          5.,   5.,   6.,  12.,   7.,   7.,  10.,  15.,  10.,   9.,  11.,
#         15.,  10.,  10.,  16.,  26.,  21.,  23.,  36.,  50.,  45.,  45.,
#         49.,  57.,  43.,  40.,  44.,  52.,  43.,  42.,  45.,  52.,  41.,
#         39.,  41.,  48.,  35.,  34.,  35.,  42.,  34.,  36.,  43.,  55.,
#         48.,  54.,  65.,  80.,  70.,  74.,  85., 101.,  89.,  88.,  90.,
#        100.,  87.,  88.,  89., 104.,  89.,  89.,  90., 106.,  96.,  94.,
#         99., 109.,  99.,  96., 102., 102., 102., 103., 103., 104., 104.,
#        105., 105.])

# %% [markdown]
# ## 方法：先进行非整数规划，再进行整数规划

# %%
total_week = 112
requirements = requirements[0:total_week]
K = 20
waste_rate = 0.1

# %%
working_hands = cp.Parameter(total_week)
waste_hands = cp.Parameter(total_week)
working_hands.value = 4 * requirements
waste_hands.value = np.array([
    4 * round(x * waste_rate) if x % 1 != 0.5 else ceil(x * waste_rate) 
    for x in requirements
])

teaching_hands = cp.Variable(total_week, integer=True)
resting_hands = cp.Variable(total_week, integer=True)
new_hands = cp.Variable((3, total_week), integer=True)

# 机械手购买的分段点
hand_price = cp.Parameter((3, 1))
hand_price.value = np.array([100, 90, 80]).reshape(3, 1)

hand_y = cp.Variable((3, total_week), boolean=True)

# %%
working_hands.value, waste_hands.value
# Out:
# (array([ 44.,  20.,  16.,  28.,  64.,  24.,  20.,  28.,  52.,  24.,  20.,
#          28.,  48.,  20.,  16.,  24.,  36.,  20.,  20.,  44., 116.,  84.,
#          68.,  80., 108.,  52.,  36.,  40.,  64.,  24.,  20.,  28.,  44.,
#          20.,  20.,  24.,  48.,  28.,  28.,  40.,  60.,  40.,  36.,  44.,
#          60.,  40.,  40.,  64., 104.,  84.,  92., 144., 200., 180., 180.,
#         196., 228., 172., 160., 176., 208., 172., 168., 180., 208., 164.,
#         156., 164., 192., 140., 136., 140., 168., 136., 144., 172., 220.,
#         192., 216., 260., 320., 280., 296., 340., 404., 356., 352., 360.,
#         400., 348., 352., 356., 416., 356., 356., 360., 424., 384., 376.,
#         396., 436., 396., 384., 408., 408., 408., 412., 412., 416., 416.,
#         420., 420.]),
#  array([ 4,  0,  0,  4,  8,  4,  0,  4,  4,  4,  0,  4,  4,  0,  0,  4,  4,
#          0,  0,  4, 12,  8,  8,  8, 12,  4,  4,  4,  8,  4,  0,  4,  4,  0,
#          0,  4,  4,  4,  4,  4,  8,  4,  4,  4,  8,  4,  4,  8, 12,  8,  8,
#         16, 20, 16, 16, 20, 24, 16, 16, 16, 20, 16, 16, 16, 20, 16, 16, 16,
#         20, 16, 12, 16, 16, 12, 16, 16, 24, 20, 20, 24, 32, 28, 28, 32, 40,
#         36, 36, 36, 40, 36, 36, 36, 40, 36, 36, 36, 44, 40, 36, 40, 44, 40,
#         40, 40, 40, 40, 40, 40, 40, 40, 40, 40]))

# %%
cons = [
    resting_hands[0] + teaching_hands[0] + working_hands[0] == 50,
    K * teaching_hands >= cp.sum(new_hands, axis=0),

    teaching_hands >= 0,
    resting_hands >= 0,
    new_hands >= 0,

    20 * hand_y[1] <= new_hands[0],
    new_hands[0] <= 20 * hand_y[0],
    20 * hand_y[2] <= new_hands[1],
    new_hands[1]  <= 20 * hand_y[1],
    new_hands[2] <= 10000 * hand_y[2]
]

# %%
for t in range(total_week - 1):
    cons.append(resting_hands[t + 1] >= working_hands[t] - waste_hands[t]),
    cons.append(resting_hands[t + 1] + working_hands[t + 1] + teaching_hands[t + 1] == \
        resting_hands[t] + working_hands[t] + teaching_hands[t] + cp.sum(new_hands, axis=0)[t] - waste_hands[t]
        )

# %%
obj = cp.Minimize(
    cp.sum(cp.multiply(new_hands, hand_price))\
    + 5 * cp.sum(resting_hands)\
    + 10 * cp.sum(teaching_hands)\
    + 10 * cp.sum(new_hands)
)

# %%
prob = cp.Problem(obj, cons)
prob.solve(solver=cp.CPLEX, verbose=True)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 04 12:07:28 AM: Your problem has 896 variables, 232 constraints, and 227 parameters.
# (CVXPY) May 04 12:07:28 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 04 12:07:28 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 04 12:07:28 AM: Compiling problem (target solver=CPLEX).
# (CVXPY) May 04 12:07:28 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> CPLEX
# (CVXPY) May 04 12:07:28 AM: Applying reduction CvxAttr2Constr
# (CVXPY) May 04 12:07:28 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) May 04 12:07:28 AM: Applying reduction QpMatrixStuffing
# (CVXPY) May 04 12:07:29 AM: Applying reduction CPLEX
# (CVXPY) May 04 12:07:29 AM: Finished problem compilation (took 3.281e-01 seconds).
# (CVXPY) May 04 12:07:29 AM: (Subsequent compilations of this problem, using the same arguments, should take less time.)
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 04 12:07:29 AM: Invoking solver CPLEX  to obtain a solution.
# Version identifier: 12.10.0.0 | 2019-11-26 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# Warning:  Non-integral bounds for integer variables rounded.
# Tried aggregator 3 times.
# MIP Presolve eliminated 785 rows and 115 columns.
# MIP Presolve modified 4 coefficients.
# Aggregator did 78 substitutions.
# Reduced MIP has 592 rows, 703 columns, and 2073 nonzeros.
# Reduced MIP has 222 binaries, 481 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (2.64 ticks)
# Probing fixed 0 vars, tightened 93 bounds.
# Probing time = 0.00 sec. (0.56 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 4 coefficients.
# Reduced MIP has 592 rows, 703 columns, and 2073 nonzeros.
# Reduced MIP has 222 binaries, 481 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (1.23 ticks)
# Probing fixed 0 vars, tightened 7 bounds.
# Probing time = 0.00 sec. (0.55 ticks)
# Clique table members: 111.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 20 threads.
# Root relaxation solution time = 0.00 sec. (2.13 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0   335483.0199   321                 335483.0199      300
#       0     0   349889.0826   321                   Cuts: 228      412
#       0     0   351142.2470   321                    Cuts: 76      458
#       0     0   351521.6775   321                    Cuts: 35      490
#       0     0   351558.3083   321                    Cuts: 25      502
#       0     0   351631.7314   321                    Cuts: 13      514
# Detecting symmetries...
#       0     0   351643.4851   321                     Cuts: 5      518
#       0     0   351648.6540   321                      MCF: 2      523
# *     0+    0                       367640.0000   351648.6540             4.35%
# *     0+    0                       366570.0000   351780.1074             4.03%
#       0     0  -1.00000e+75     0   366570.0000   351780.1074      523    4.03%
# Detecting symmetries...
#       0     2   351648.6540   416   366570.0000   351780.1074      523    4.03%
# Elapsed time = 0.38 sec. (158.90 ticks, tree = 0.02 MB, solutions = 2)
# *    26+    6                       365610.0000   351780.1074             3.78%
# *    42+    8                       365600.0000   351780.1074             3.78%
# *    49+    3                       365470.0000   351780.1074             3.75%
# *    54+    2                       365455.0000   351780.1074             3.74%
# *    82+    1                       365175.0000   351780.1074             3.67%
# *   311+   62                       363995.0000   351960.3817             3.31%
# *  1682+  943                       362185.0000   351960.3817             2.82%
# *  2900+ 2169                       361465.0000   351960.3817             2.63%
# *  3663+ 2705                       361330.0000   352057.2922             2.57%
# *  4811+ 2240                       360130.0000   352103.0611             2.23%
# *  5119+ 2901                       359370.0000   352103.0611             2.02%
# *  5302+ 2240                       358715.0000   352103.0611             1.84%
# *  5302+ 2240                       358680.0000   352103.0611             1.83%
# *  5304+ 2876                       358600.0000   352103.0611             1.81%
# *  5304+ 2876                       358580.0000   352103.0611             1.81%
# *  5304+ 2876                       358550.0000   352103.0611             1.80%
#    5304  2874   358550.0000     0   358550.0000   352103.0611    11007    1.80%
#
# Performing restart 1
#
# Repeating presolve.
# Tried aggregator 1 time.
# MIP Presolve modified 73 coefficients.
# Reduced MIP has 592 rows, 703 columns, and 2066 nonzeros.
# Reduced MIP has 222 binaries, 481 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (1.49 ticks)
# Tried aggregator 1 time.
# MIP Presolve modified 29 coefficients.
# Reduced MIP has 592 rows, 703 columns, and 2066 nonzeros.
# Reduced MIP has 222 binaries, 481 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (1.78 ticks)
# Represolve time = 0.03 sec. (6.74 ticks)
#    5305     0   353355.5445   428   358550.0000     Cuts: 248    18222    1.45%
#    5305     0   354392.0534   428   358550.0000     Cuts: 248    18360    1.16%
#    5305     0   355093.1353   428   358550.0000     Cuts: 248    18484    0.96%
#    5305     0   355442.2075   428   358550.0000     Cuts: 188    18559    0.87%
#    5305     0   355583.2924   428   358550.0000     Cuts: 113    18623    0.83%
#    5305     0   355711.8076   428   358550.0000     Cuts: 118    18698    0.79%
#    5305     0   355840.0056   428   358550.0000      Cuts: 79    18758    0.76%
#    5305     0   355904.1861   428   358550.0000      Cuts: 82    18800    0.74%
#    5305     0   355916.4759   428   358550.0000      Cuts: 32    18831    0.73%
#    5305     0   356003.7739   428   358550.0000      Cuts: 61    18874    0.71%
#    5305     0   356073.9814   428   358550.0000      Cuts: 50    18930    0.69%
#    5305     0   356124.9495   428   358550.0000      Cuts: 34    18948    0.68%
#    5305     0   356164.8714   428   358550.0000      Cuts: 38    18980    0.67%
#    5305     0   356186.9739   428   358550.0000      Cuts: 47    19001    0.66%
#    5305     0   356197.6828   428   358550.0000       Cuts: 3    19004    0.66%
#    5305     0   356203.8344   428   358550.0000    MIRcuts: 2    19006    0.64%
#    5305     0   356300.8356   428   358550.0000      Cuts: 12    19032    0.63%
#    5305     0   356331.8190   428   358550.0000      Cuts: 20    19040    0.62%
#    5305     0   356360.5921   428   358550.0000      Cuts: 10    19047    0.61%
#    5305     0   356361.6834   428   358550.0000      Cuts: 13    19055    0.61%
#    5305     2   356361.6834   431   358550.0000   356361.6834    19055    0.61%
# *  6202+  383                       358155.0000   356717.3668             0.40%
#    7429   669   357198.9983   305   358155.0000   356841.1186    27895    0.37%
# * 12352+ 4238                       358070.0000   356892.7493             0.33%
# * 13439+ 4550                       358030.0000   356894.7519             0.32%
# * 13517+ 4465                       357735.0000   356928.0896             0.23%
# * 13641+ 4718                       357720.0000   356928.0896             0.22%
# * 13650+ 4465                       357545.0000   356928.0896             0.17%
# * 13714+ 4718                       357545.0000   356928.0896             0.17%
# * 13762+ 4817                       357545.0000   356928.0896             0.17%
#   13998  2738   357426.2348   300   357545.0000   356928.0896    63538    0.17%
#   19889  5246        cutoff         357545.0000   356962.2332    94705    0.16%
#   27646  8003   357481.4309   314   357545.0000   356993.1885   131254    0.15%
#   33901 10895   357329.6777   318   357545.0000   357021.1515   166735    0.15%
#   41914 13234   357377.5719   315   357545.0000   357048.3424   213878    0.14%
#   48630 15222   357427.4819   302   357545.0000   357087.4164   261854    0.13%
# * 52379+16793                       357530.0000   357100.9324             0.12%
#
# Performing restart 2
#
# Repeating presolve.
# Tried aggregator 1 time.
# MIP Presolve eliminated 26 rows and 26 columns.
# MIP Presolve modified 70 coefficients.
# Reduced MIP has 566 rows, 677 columns, and 1983 nonzeros.
# Reduced MIP has 209 binaries, 468 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (1.42 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 566 rows, 677 columns, and 1983 nonzeros.
# Reduced MIP has 209 binaries, 468 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (1.73 ticks)
# Represolve time = 0.08 sec. (32.30 ticks)
#   60429     0   356392.8611   433   357530.0000      Cuts: 31   347119    0.11%
#   60429     0   356402.9577   433   357530.0000      Cuts: 13   347143    0.11%
#   60429     0   356420.7388   433   357530.0000      Cuts: 24   347156    0.11%
#   60429     0   356422.9292   433   357530.0000   MIRcuts: 18   347167    0.11%
#   60429     0   356424.1418   433   357530.0000    MIRcuts: 5   347171    0.11%
#   60429     0   356424.2795   433   357530.0000    MIRcuts: 3   347173    0.11%
#   60433     4   356494.6212   374   357530.0000   357193.9669   347191    0.09%
# Elapsed time = 11.83 sec. (4027.43 ticks, tree = 0.02 MB, solutions = 35)
#   72450  4038   357518.5097   101   357530.0000   357193.9669   399110    0.09%
#   86210  7065   357460.4612   227   357530.0000   357285.4555   460552    0.07%
#  100196 10050   357472.8466   211   357530.0000   357337.2022   522231    0.05%
#  114923 13315   357491.7584   191   357530.0000   357379.7774   584446    0.04%
#  129959 15059        cutoff         357530.0000   357413.2663   638391    0.03%
#  145527 15408   357487.5617   171   357530.0000   357442.0993   708191    0.02%
#  161972 14237        cutoff         357530.0000   357468.7918   773743    0.02%
#
# Implied bound cuts applied:  1
# Flow cuts applied:  14
# Mixed integer rounding cuts applied:  141
# Zero-half cuts applied:  1
# Multi commodity flow cuts applied:  1
# Lift and project cuts applied:  24
# Gomory fractional cuts applied:  35
#
# Root node processing (before b&c):
#   Real time             =    0.36 sec. (158.56 ticks)
# Parallel b&c, 20 threads:
#   Real time             =   32.05 sec. (11189.75 ticks)
#   Sync time (average)   =    5.13 sec.
#   Wait time (average)   =    0.07 sec.
#                           ------------
# Total (root+branch&cut) =   32.41 sec. (11348.31 ticks)
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 04 12:08:01 AM: Problem status: optimal
# (CVXPY) May 04 12:08:01 AM: Optimal value: 3.575e+05
# (CVXPY) May 04 12:08:01 AM: Compilation took 3.281e-01 seconds
# (CVXPY) May 04 12:08:01 AM: Solver (including time spent in interface) took 3.243e+01 seconds
# 357530.0000000042

# %%
working_bodies = cp.Parameter(total_week)
waste_bodies = cp.Parameter(total_week)
working_bodies.value = requirements
waste_bodies.value = np.array([
    round(x * waste_rate) if x % 1 != 0.5 else ceil(x * waste_rate) 
    for x in requirements
])

resting_bodies = cp.Variable(total_week, integer=True)
new_bodies = cp.Variable((3, total_week), integer=True)

# 机械手购买的分段点
body_price = cp.Parameter((3, 1))
body_price.value = np.array([200, 180, 160]).reshape(3, 1)

body_y = cp.Variable((3, total_week), boolean=True)

# %%
cons2 = [
    resting_bodies[0] + working_bodies[0] == 13,

    resting_bodies >= 0,
    new_bodies >= 0,

    5 * body_y[1] <= new_bodies[0],
    new_bodies[0] <= 5 * body_y[0],
    5 * body_y[2] <= new_bodies[1],
    new_bodies[1]  <= 5 * body_y[1],
    new_bodies[2] <= 10000 * body_y[2]
]

for t in range(total_week - 1):
    cons2.append(resting_bodies[t + 1] + working_bodies[t + 1]== \
        resting_bodies[t] + working_bodies[t] + cp.sum(new_bodies, axis=0)[t] - waste_bodies[t]
        )

# %%
obj2 = cp.Minimize(
    cp.sum(cp.multiply(new_bodies, body_price))\
    + 10 * cp.sum(resting_bodies)
)

# %%
prob2 = cp.Problem(obj2, cons2)
prob2.solve(solver=cp.CPLEX, verbose=True)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) May 04 12:08:02 AM: Your problem has 784 variables, 119 constraints, and 227 parameters.
# (CVXPY) May 04 12:08:02 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 04 12:08:02 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 04 12:08:02 AM: Compiling problem (target solver=CPLEX).
# (CVXPY) May 04 12:08:02 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> CPLEX
# (CVXPY) May 04 12:08:02 AM: Applying reduction CvxAttr2Constr
# (CVXPY) May 04 12:08:02 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) May 04 12:08:02 AM: Applying reduction QpMatrixStuffing
# (CVXPY) May 04 12:08:02 AM: Applying reduction CPLEX
# (CVXPY) May 04 12:08:02 AM: Finished problem compilation (took 2.459e-01 seconds).
# (CVXPY) May 04 12:08:02 AM: (Subsequent compilations of this problem, using the same arguments, should take less time.)
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 04 12:08:02 AM: Invoking solver CPLEX  to obtain a solution.
# Version identifier: 12.10.0.0 | 2019-11-26 | 843d4de2ae
# CPXPARAM_Read_DataCheck                          1
# Warning:  Non-integral bounds for integer variables rounded.
# Tried aggregator 2 times.
# MIP Presolve eliminated 563 rows and 116 columns.
# MIP Presolve added 1 rows and 0 columns.
# Aggregator did 111 substitutions.
# Reduced MIP has 447 rows, 557 columns, and 1489 nonzeros.
# Reduced MIP has 222 binaries, 335 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (1.75 ticks)
# Found incumbent of value 7.9814693e+08 after 0.02 sec. (3.24 ticks)
# Probing fixed 0 vars, tightened 2 bounds.
# Probing time = 0.00 sec. (1.53 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 3 coefficients.
# Reduced MIP has 447 rows, 557 columns, and 1489 nonzeros.
# Reduced MIP has 222 binaries, 335 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (1.02 ticks)
# Probing fixed 0 vars, tightened 1 bounds.
# Probing time = 0.00 sec. (1.80 ticks)
# Clique table members: 111.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 20 threads.
# Root relaxation solution time = 0.00 sec. (1.08 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       7.98147e+08  -5.77293e+07           107.23%
#       0     0    93936.9930   240   7.98147e+08    93936.9930      169   99.99%
#       0     0   100273.5968   240   7.98147e+08     Cuts: 139      248   99.99%
#       0     0   100853.8206   240   7.98147e+08      Cuts: 48      286   99.99%
#       0     0   100889.5822   240   7.98147e+08      Cuts: 14      296   99.99%
#       0     0   100897.1284   240   7.98147e+08      Cuts: 15      308   99.99%
#       0     0   100911.5660   240   7.98147e+08      Cuts: 10      321   99.99%
# Detecting symmetries...
#       0     0   100920.4135   240   7.98147e+08       Cuts: 9      330   99.99%
#       0     0   100925.9672   240   7.98147e+08       Cuts: 7      335   99.99%
#       0     0   100930.2108   240   7.98147e+08       Cuts: 5      342   99.99%
# *     0+    0                       106300.0000   100930.2108             5.05%
# *     0+    0                       106150.0000   100930.2108             4.92%
# *     0+    0                       106010.0000   100956.7344             4.77%
#       0     0  -1.00000e+75     0   106010.0000   100956.7344      342    4.77%
# Detecting symmetries...
#       0     2   100930.2108   271   106010.0000   101023.8320      342    4.70%
# Elapsed time = 0.22 sec. (59.16 ticks, tree = 0.02 MB, solutions = 4)
# *    27+   13                       105870.0000   101023.8320             4.58%
# *    27+   18                       105870.0000   101023.8320             4.58%
# *    81+    2                       105620.0000   101023.8320             4.35%
# *    87+    3                       105470.0000   101023.8320             4.22%
#
# Performing restart 1
#
# Repeating presolve.
# Tried aggregator 1 time.
# MIP Presolve eliminated 2 rows and 2 columns.
# MIP Presolve modified 160 coefficients.
# Reduced MIP has 445 rows, 555 columns, and 1482 nonzeros.
# Reduced MIP has 221 binaries, 334 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (1.13 ticks)
# Tried aggregator 1 time.
# MIP Presolve modified 41 coefficients.
# Reduced MIP has 445 rows, 555 columns, and 1482 nonzeros.
# Reduced MIP has 221 binaries, 334 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (1.03 ticks)
# Represolve time = 0.03 sec. (4.25 ticks)
# *  5523+    0                       105290.0000   101675.9680             3.43%
#    5523     0   103540.1134   296   105290.0000     Cuts: 211    16251    1.66%
#    5523     0   103963.8493   296   105290.0000     Cuts: 211    16358    1.26%
#    5523     0   104161.2882   296   105290.0000     Cuts: 157    16448    1.07%
#    5523     0   104256.2276   296   105290.0000     Cuts: 129    16506    0.98%
# *  5523+    0                       105250.0000   104256.2276             0.94%
#    5523     0   104342.6720   296   105250.0000      Cuts: 87    16562    0.86%
#    5523     0   104379.0184   296   105250.0000      Cuts: 61    16601    0.83%
#    5523     0   104416.8813   296   105250.0000     Cuts: 109    16649    0.79%
#    5523     0   104466.9525   296   105250.0000      Cuts: 77    16696    0.74%
#    5523     0   104484.2503   296   105250.0000      Cuts: 35    16710    0.73%
# *  5523+    0                       104930.0000   104484.2503             0.42%
#    5523     0   104492.0527   296   104930.0000      Cuts: 26    16720    0.42%
#    5523     0   104544.4356   296   104930.0000      Cuts: 26    16759    0.37%
#    5523     0   104562.1848   296   104930.0000      Cuts: 57    16790    0.35%
#    5523     0   104581.5911   296   104930.0000      Cuts: 32    16816    0.33%
#    5523     0   104591.1070   296   104930.0000      Cuts: 37    16831    0.32%
#    5523     0   104602.2400   296   104930.0000      Cuts: 34    16848    0.31%
#    5523     0   104606.1114   296   104930.0000      Cuts: 11    16858    0.31%
#    5523     0   104614.8425   296   104930.0000      Cuts: 20    16878    0.30%
#    5523     0   104618.9527   296   104930.0000      Cuts: 23    16888    0.30%
#    5523     0   104621.5848   296   104930.0000      Cuts: 20    16898    0.29%
#    5523     0   104622.3305   296   104930.0000      Cuts: 18    16904    0.29%
# *  5523+    0                       104730.0000   104622.3305             0.10%
#    5523     1   104629.7351   147   104730.0000   104622.3305    16904    0.10%
#
# Implied bound cuts applied:  3
# Flow cuts applied:  36
# Mixed integer rounding cuts applied:  109
# Zero-half cuts applied:  17
# Lift and project cuts applied:  28
# Gomory fractional cuts applied:  52
#
# Root node processing (before b&c):
#   Real time             =    0.22 sec. (58.90 ticks)
# Parallel b&c, 20 threads:
#   Real time             =    1.84 sec. (584.38 ticks)
#   Sync time (average)   =    0.22 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    2.06 sec. (643.28 ticks)
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 04 12:08:04 AM: Problem status: optimal
# (CVXPY) May 04 12:08:04 AM: Optimal value: 1.047e+05
# (CVXPY) May 04 12:08:04 AM: Compilation took 2.459e-01 seconds
# (CVXPY) May 04 12:08:04 AM: Solver (including time spent in interface) took 2.072e+00 seconds
# 104729.99999999948

# %%
working_hands.value, resting_hands.value, waste_hands.value
# Out:
# (array([ 44.,  20.,  16.,  28.,  64.,  24.,  20.,  28.,  52.,  24.,  20.,
#          28.,  48.,  20.,  16.,  24.,  36.,  20.,  20.,  44., 116.,  84.,
#          68.,  80., 108.,  52.,  36.,  40.,  64.,  24.,  20.,  28.,  44.,
#          20.,  20.,  24.,  48.,  28.,  28.,  40.,  60.,  40.,  36.,  44.,
#          60.,  40.,  40.,  64., 104.,  84.,  92., 144., 200., 180., 180.,
#         196., 228., 172., 160., 176., 208., 172., 168., 180., 208., 164.,
#         156., 164., 192., 140., 136., 140., 168., 136., 144., 172., 220.,
#         192., 216., 260., 320., 280., 296., 340., 404., 356., 352., 360.,
#         400., 348., 352., 356., 416., 356., 356., 360., 424., 384., 376.,
#         396., 436., 396., 384., 408., 408., 408., 412., 412., 416., 416.,
#         420., 420.]),
#  array([  5.,  40.,  44.,  30.,  24.,  56.,  56.,  47.,  24.,  48.,  48.,
#          39.,  24.,  48.,  52.,  44.,  28.,  40.,  39.,  20.,  91., 111.,
#         119.,  98.,  72., 116., 128., 120.,  92., 124., 124., 116.,  96.,
#         116., 116., 112.,  84., 100.,  96.,  80.,  56.,  68.,  68.,  55.,
#          40.,  52.,  46.,  36.,  88.,  96.,  76.,  84., 185., 185., 164.,
#         228., 176., 208., 204., 169., 179., 195., 183., 152., 164., 188.,
#         180., 154., 148., 180., 168., 150., 136., 152., 129., 128., 217.,
#         221., 172., 196., 293., 301., 252., 268., 356., 364., 325., 424.,
#         348., 360., 317., 316., 384., 404., 368., 320., 384., 380., 345.,
#         340., 396., 392., 356., 453., 413., 368., 417., 372., 421., 376.,
#         420., 380.]),
#  array([ 4,  0,  0,  4,  8,  4,  0,  4,  4,  4,  0,  4,  4,  0,  0,  4,  4,
#          0,  0,  4, 12,  8,  8,  8, 12,  4,  4,  4,  8,  4,  0,  4,  4,  0,
#          0,  4,  4,  4,  4,  4,  8,  4,  4,  4,  8,  4,  4,  8, 12,  8,  8,
#         16, 20, 16, 16, 20, 24, 16, 16, 16, 20, 16, 16, 16, 20, 16, 16, 16,
#         20, 16, 12, 16, 16, 12, 16, 16, 24, 20, 20, 24, 32, 28, 28, 32, 40,
#         36, 36, 36, 40, 36, 36, 36, 40, 36, 36, 36, 44, 40, 36, 40, 44, 40,
#         40, 40, 40, 40, 40, 40, 40, 40, 40, 40]))

# %%
hand_y.value
# Out:
# array([[ 1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#         -3.98311423e-13,  0.00000000e+00, -2.24050175e-13,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          4.23238375e-13,  1.00000000e+00,  1.15946128e-13,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.20792265e-13,  0.00000000e+00,  1.00000000e+00,
#          3.31458551e-13,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00, -4.23323897e-13,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  1.87217983e-13,  1.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  7.68536784e-13,
#         -3.98311423e-13,  0.00000000e+00, -2.24050175e-13,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.42759319e-13,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.20792265e-13,  0.00000000e+00,  1.00000000e+00,
#          3.31458551e-13,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  1.00000000e+00, -4.23323897e-13,
#          0.00000000e+00, -2.86658211e-12,  1.00000000e+00,
#         -5.07512240e-13,  1.87217983e-13,  1.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00]])

# %%
new_hands.value, teaching_hands.value
# Out:
# (array([[ 1.40000000e+01,  0.00000000e+00,  0.00000000e+00,
#           2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  4.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  8.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00, -8.33327570e-12,  0.00000000e+00,
#           1.10000000e+01,  2.00000000e+01,  0.00000000e+00,
#          -7.96622846e-12,  0.00000000e+00,  9.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  4.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  2.00000000e+01,  2.00000000e+01,
#           0.00000000e+00,  0.00000000e+00,  2.00000000e+01,
#           2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#           2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  2.00000000e+01,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  2.00000000e+01,  2.31892257e-12,
#           0.00000000e+00,  0.00000000e+00,  2.00000000e+01,
#           0.00000000e+00,  0.00000000e+00,  2.00000000e+01,
#           2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#           2.00000000e+01,  2.00000000e+01,  0.00000000e+00,
#           0.00000000e+00,  2.00000000e+01,  2.00000000e+01,
#           2.41584530e-12,  0.00000000e+00,  2.00000000e+01,
#           6.62917102e-12,  0.00000000e+00,  0.00000000e+00,
#           2.00000000e+01,  2.00000000e+01, -8.46647794e-12,
#           0.00000000e+00,  0.00000000e+00,  2.00000000e+01,
#           0.00000000e+00,  3.74435966e-12,  2.00000000e+01,
#           2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#           2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#           2.00000000e+01,  0.00000000e+00,  2.00000000e+01,
#           0.00000000e+00,  2.00000000e+01,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.20000000e+01,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.95351271e-12,  2.00000000e+01,  1.53707357e-11,
#          -7.96622846e-12,  0.00000000e+00, -4.48100351e-12,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  1.00000000e+00,  2.00000000e+01,
#           0.00000000e+00,  0.00000000e+00,  2.00000000e+01,
#           2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#           2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  2.00000000e+01,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  1.60000000e+01,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  8.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  2.00000000e+01,
#           2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#           2.00000000e+01,  2.00000000e+01,  0.00000000e+00,
#           0.00000000e+00,  2.00000000e+01,  2.00000000e+01,
#           2.41584530e-12,  0.00000000e+00,  2.00000000e+01,
#           6.62917102e-12,  0.00000000e+00,  0.00000000e+00,
#           2.00000000e+01,  2.00000000e+01, -8.46647794e-12,
#           0.00000000e+00, -5.73316422e-11,  2.00000000e+01,
#          -1.01502448e-11,  3.74435966e-12,  2.00000000e+01,
#           2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#           2.00000000e+01,  0.00000000e+00,  0.00000000e+00,
#           2.00000000e+01,  0.00000000e+00,  2.00000000e+01,
#           0.00000000e+00,  2.00000000e+01,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           6.39383208e-12,  1.00000000e+02, -1.96967187e-13,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          -1.05378898e-11,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  5.50000000e+01,
#           0.00000000e+00,  0.00000000e+00,  3.30000000e+01,
#           1.24000000e+02,  0.00000000e+00,  0.00000000e+00,
#           5.10000000e+01,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  1.50000000e+01,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           1.30000000e+01,  0.00000000e+00,  0.00000000e+00,
#          -2.31892257e-12,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  8.00000000e+00,
#           1.05000000e+02,  0.00000000e+00,  0.00000000e+00,
#           5.20000000e+01,  1.32000000e+02,  0.00000000e+00,
#           0.00000000e+00,  5.20000000e+01,  1.35000000e+02,
#          -4.83169060e-12,  0.00000000e+00,  9.60000000e+01,
#          -1.32583420e-11,  0.00000000e+00,  0.00000000e+00,
#           4.00000000e+00,  1.16000000e+02,  0.00000000e+00,
#          -3.55592074e-10,  0.00000000e+00,  1.16000000e+02,
#           1.05246808e-11,  0.00000000e+00,  1.50000000e+01,
#           8.90000000e+01,  0.00000000e+00,  0.00000000e+00,
#           1.13000000e+02,  0.00000000e+00,  0.00000000e+00,
#           4.80000000e+01,  0.00000000e+00,  4.80000000e+01,
#           0.00000000e+00,  4.30000000e+01,  0.00000000e+00,
#          -0.00000000e+00]]),
#  array([ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00,  2.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -4.15667500e-13,  4.21884749e-15,  1.00000000e+00,  7.00000000e+00,
#          7.52360318e-13, -7.96622846e-13, -8.14981786e-16,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          7.10542736e-15, -1.09286568e-15, -5.26894490e-13,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.00000000e+00,  5.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  4.00000000e+00,  9.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  5.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  3.00000000e+00,
#          0.00000000e+00, -5.72177743e-15,  6.64495823e-12,  2.00000000e+00,
#         -2.33058017e-12,  0.00000000e+00,  0.00000000e+00,  2.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,  8.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  5.00000000e+00,  9.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  5.00000000e+00,  9.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  7.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  3.00000000e+00,  8.00000000e+00,
#         -8.40264859e-13, -1.77796037e-11, -2.88662794e-12,  8.00000000e+00,
#          0.00000000e+00,  3.97903932e-13,  3.00000000e+00,  7.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  8.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  5.00000000e+00,  0.00000000e+00,  5.00000000e+00,
#          0.00000000e+00,  5.00000000e+00,  0.00000000e+00,  0.00000000e+00]))

# %% [markdown]
# ## 输出变量

# %%
prob.value + prob2.value
# Out:
# 462260.00000000367

# %%
answers = [
    np.round(np.sum(new_bodies.value, axis=0)),
    np.round(np.sum(new_hands.value, axis=0)),
    np.round(resting_hands.value),
    np.round(resting_bodies.value),
    np.round(np.sum(new_hands.value, axis=0) + teaching_hands.value),
    np.sum(np.round(new_bodies.value) * body_price.value, axis=0) + \
        np.sum(np.round(new_hands.value) * hand_price.value, axis=0) + \
        5 * np.round(resting_hands.value) + \
        10 * np.round(resting_bodies.value) + \
        10 * np.round(np.sum(new_hands.value, axis=0) + teaching_hands.value)
]

# %%
answers[5].sum()
# Out:
# 462260.0

# %%
answers[5][104:112].sum()
# Out:
# 52475.0

# %%
answers = np.array(answers).T

# %%
answers[25]
# Out:
# array([  0.,   0., 116.,  11.,   0., 690.])

# %%
part_ans = np.array(answers[np.arange(104, 112), :], dtype=np.int32)
part_ans = np.concatenate([part_ans, np.sum(part_ans, keepdims=True, axis=0)])

# %%
df = pd.DataFrame(part_ans, index=list(range(105, 113)) + ['total'],
    # columns=['购买的容器艇数量', '购买的操作手数量', '保养的操作手数量', '保养的容器艇数量', '参与训练的操作手数量', '总成本']
)
df.to_excel('prob5_part2_answer.xlsx')
df
# Out:
#         0    1     2   3    4      5
# 105     0    0   413  10    0   2165
# 106    21   88   368   0   93  14070
# 107     0    0   417  10    0   2185
# 108    21   88   372   0   93  14090
# 109     0    0   421  10    0   2205
# 110    21   83   376   0   88  13660
# 111     0    0   420  10    0   2200
# 112     0    0   380   0    0   1900
# total  63  259  3167  40  274  52475

# %% [markdown]
# ## 问题五·方案一开头条件
